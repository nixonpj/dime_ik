# %% [markdown]
# # Kanoon Judgements
#
# We have scraped judgements from IndiaKanoon for Gauhati High Court in 2019. There are approximately 54 thousand cases listed here. This program goes through each case and parse relevant information into a pandas dataframe for further analysis.

# %%
import os 
import re
import time
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import ik_parsing as ik
head, tail = os.path.split(os.getcwd())
list_of_filenames = os.listdir(os.path.join(head, '2019', '2019'))

# %% [markdown]
# ## 1. Creating a Citation Network
# Looping over the text of each case, create a dictionary with the key as a kanoon case id and the value as a set of kanoon case ids or laws that are cited in the text. So for example, if kanoon case id 10 cites a kanoon document id number 201374 we have in our network 10: {201374}.

# %%
# Tried using plain string search but it wasnt a significant improvement. Plus regex helps search 
# for /[a-z]/ type results which would be difficult with plain string query. Leaving it here for the time being.

citation_network = {}
start_time = time.time()
        
        
def parse_text(text):
    search_term = """href="/doc/"""
    start = 0
    res_dict = {filename[:-4]: set()}
    while start!=-1:
        start = text.find(search_term) # should be the where you find the h of href
        end = start+11+text[start+11:].find('/')  # should be where you end the number post /doc/
        citation = text[start+11:end]
        if citation.isnumeric():
            res_dict[filename[:-4]].add(citation)
        text = text[end:]
    return res_dict
    
        
# for filename in list_of_filenames:
#     with open('..\\2019\\2019\\'+filename, encoding="utf8") as f:
#         text = f.read().replace(" ","")
#         citations = parse_text(text)
#         if citations[filename[:-4]]:
#             citation_network.update(citations)
    
        
print(f"--- {(time.time() - start_time)} seconds ---") #Almost the same amount of time so no savings
# Out:
# --- 0.0 seconds ---

# %%
# We loop over each file and find all citations using regex and add it to the citations dictionary with the case 
# as the key and a set of citations as the value.

citation_network = {}
start_time = time.time()

for filename in list_of_filenames:
    with open(os.path.join(os.path.join(head, '2019', '2019', filename)), encoding="utf8") as f:
        text = f.read()
        citations = (set(re.findall("""/[a-zA-z]+/(\d*)""", text, flags=re.IGNORECASE)))
        citations.discard('')
#         citations.discard(filename[:-4])   # Every case cites itself. Comment this out if you do not want that.
        if citations:
            citation_network[filename[:-4]] = citations
    
print(f"--- {(time.time() - start_time)} seconds ---")  # takes 1000-1500 seconds
# Out:
# --- 1574.8231234550476 seconds ---

# %%
# First we create a sparse matrix by identifying the indexes where the value is 1 (citation present).
# Convert this sparse matrix to a sparse dataframe with index and col names as list of filenames. 

from scipy.sparse import coo_matrix

start_time = time.time()
row_indices = []
col_indices = []

for i, filename in enumerate(list_of_filenames):
    if citation_network[filename[:-4]]:
        for citation in citation_network[filename[:-4]]:
            if citation+'.txt' in list_of_filenames:
                row_indices.append(i)
                col_indices.append(list_of_filenames.index(citation+'.txt'))
        
data = np.ones(len(row_indices))

m = len(list_of_filenames)
network_matrix = coo_matrix((data, (row_indices, col_indices)), shape = (m, m))
citations_df = pd.DataFrame.sparse.from_spmatrix(network_matrix, index=list_of_filenames, columns=list_of_filenames)
print(citations_df.head(5))
# citations_df.to_csv('citations_sparse.csv')

print(f"--- {(time.time() - start_time)} seconds ---")  # takes 180-240 seconds
# Out:
# --- 134.1075940132141 seconds ---
#                100006976.txt  100009202.txt  100013560.txt  100015777.txt  \
# 100006976.txt            1.0            0.0            0.0            0.0
# 100009202.txt            0.0            1.0            0.0            0.0
# 100013560.txt            0.0            0.0            1.0            0.0
# 100015777.txt            0.0            0.0            0.0            1.0
# 100020544.txt            0.0            0.0            0.0            0.0
#
#                100020544.txt  100021334.txt  100027104.txt  100032828.txt  \
# 100006976.txt            0.0            0.0            0.0            0.0
# 100009202.txt            0.0            0.0            0.0            0.0
# 100013560.txt            0.0            0.0            0.0            0.0
# 100015777.txt            0.0            0.0            0.0            0.0
# 100020544.txt            1.0            0.0            0.0            0.0
#
#                100033233.txt  100034166.txt  ...  99976296.txt  99980084.txt  \
# 100006976.txt            0.0            0.0  ...           0.0           0.0
# 100009202.txt            0.0            0.0  ...           0.0           0.0
# 100013560.txt            0.0            0.0  ...           0.0           0.0
# 100015777.txt            0.0            0.0  ...           0.0           0.0
# 100020544.txt            0.0            0.0  ...           0.0           0.0
#
#                99980145.txt  99982903.txt  99987791.txt  99991536.txt  \
# 100006976.txt           0.0           0.0           0.0           0.0
# 100009202.txt           0.0           0.0           0.0           0.0
# 100013560.txt           0.0           0.0           0.0           0.0
# 100015777.txt           0.0           0.0           0.0           0.0
# 100020544.txt           0.0           0.0           0.0           0.0
#
#                99991675.txt  99992502.txt  99992685.txt  99996598.txt
# 100006976.txt           0.0           0.0           0.0           0.0
# 100009202.txt           0.0           0.0           0.0           0.0
# 100013560.txt           0.0           0.0           0.0           0.0
# 100015777.txt           0.0           0.0           0.0           0.0
# 100020544.txt           0.0           0.0           0.0           0.0
#
# [5 rows x 51302 columns]

# %%
# Create a list of case-citation tuples excluding all cases that have themselves as citation 
# and convert this list to DF for export.

edge_list = [ ]

for case, citation_set in citation_network.items():
    if citation_set:
        edge_list.extend(((case, citation) for citation in citation_set if case!=citation))

df = pd.DataFrame(edge_list, columns = ['Case', 'Citation'])
df.to_csv('citation_edge_list.csv', index=False) 
df.head(5)

# %% [markdown]
# # Parsing
#
# Use html tags as well as string manipulation (regex) to extract useful information out of the judgement text.

# %%
import importlib
importlib.reload(ik)
# Out:
# <module 'ik_parsing' from 'C:\\Users\\Nick\\Desktop\\Chicago\\DIME\\kanoon\\ik_parsing.py'>

# %%
# We loop over each file and find all citations using regex and add it to the citations dictionary with the case 
# as the key and a set of citations as the value.

network = {}
titles = []
dates = []
courts = []
cnr_nums = []
case_nums = []
petitioner = []
respondent = []
petitioner_advocates = []
respondent_advocates = []
judges = []
count = 0

start_time = time.time()  

for filename in list_of_filenames:
    count+=1
    if count>500:
        break
    with open(os.path.join(os.path.join(head, '2019', '2019', filename)), encoding="utf8") as f:
        soup = BeautifulSoup(f, 'html.parser')
        text = soup.get_text().lower()
#         if count==2:
#             print(text)
#             break
        try:
            courts.append(soup.find("div", {"class": "docsource_main"}).string)
            title, date = soup.title.string.split(' on ')
            titles.append(title)
            dates.append(date)
        except AttributeError:
            titles.append(np.nan)
            dates.append(np.nan)
            courts.append(np.nan)
#         print(soup.get_text())
#         print(soup.title.string)
#         print(soup.find("div", {"class": "docsource_main"}).string)
        case_nums.append(ik.extract_case_num(text))
        petitioner.append(ik.extract_petitioner(text))
        respondent.append(ik.extract_respondent(text))
        pet_adv, resp_adv = ik.extract_petitioner_advocate(text)
        petitioner_advocates.append(pet_adv)
        respondent_advocates.append(resp_adv)
        cnr_nums.append(ik.extract_cnr(text))
        judges.append(ik.extract_judges(text))
             
    
print(f"--- {(time.time() - start_time)} seconds ---")  # takes 1000-1500 seconds

# With 5000 files it takes 60-220 seconds to append to lists.
# Out:
# --- 10.067937850952148 seconds ---

# %%
df = pd.DataFrame({'file':list_of_filenames[:500], 'cnr_num': cnr_nums, 'title': titles, 'date': dates, 'court': courts, 
                   'case_number': case_nums, 'petitioner': petitioner, 'respondent':respondent, 
                   'petitioner_advocate': petitioner_advocates, 'respondent_advocate': respondent_advocates,
                   'judge': judges})
df['bench_size'] = df.loc[:,'judge'].dropna().apply(len)
df['chief_justice'] = df.loc[:,'judge'].dropna().apply(lambda x: (any('chief' in item for item in x)))

keywords_state = ['state', 'government', 'commissioner', 'national', 'india', 'indian', 'public', 'magistrate']
df['state'] = df.loc[:,'title'].dropna().apply(lambda x: (any(keyword in x.lower() for keyword in keywords_state)))

keywords_business = ['pvt', 'private', 'limited', 'ltd', 'company', 'co.', 'llc']
df['petitioner_business'] = df.loc[:,'petitioner'].dropna().apply(lambda x: (any(keyword in x.lower() for keyword in keywords_business)))
df['respondent_business'] = df.loc[:,'respondent'].dropna().apply(lambda x: (any(keyword in x.lower() for keyword in keywords_business)))

keywords_male = ['shri', 'mr.', 'master']
keywords_female = ['smt', 'mrs.', 'ms']

df.replace('\n', ' ', regex = True, inplace = True)
df.head()
# Out:
#             file             cnr_num  \
# 0  100006976.txt   gahc010142142019
# 1  100009202.txt   gahc010130082013
# 2  100013560.txt   gahc010076622019
# 3  100015777.txt   gahc010021642017
# 4  100020544.txt   gahc010133782017
#
#                                                title              date  \
# 0  The Commissioner Of Central Goods ... vs Dhara...  25 October, 2019
# 1        Jufiul Huda vs The State Of Assam And 3 Ors    11 March, 2019
# 2           Amena Khatun vs Union Of India And 5 Ors    29 April, 2019
# 3      Raj Kumar Singh vs The State Of Assam And Anr      3 June, 2019
# 4  National Insurance Co. Ltd vs Chittarlekha Bor...    30 April, 2019
#
#                 court                       case_number  \
# 0  Gauhati High Court  case no. : i.a.(civil) 2085/2019
# 1  Gauhati High Court        case no. : wp(c) 2866/2013
# 2  Gauhati High Court        case no. : wp(c) 2410/2019
# 3  Gauhati High Court    case no. : crl.rev.p. 140/2017
# 4  Gauhati High Court  case no. : i.a.(civil) 2261/2017
#
#                                           petitioner  \
# 0  1:the commissioner of central goods and servic...
# 1  1:jufiul huda             s/o nurul huda r/o s...
# 2  1:amena khatun             w/o. hamed ali @ ab...
# 3  1:raj kumar singh             s/o sri hetrm si...
# 4  1:national insurance co. ltd.             regd...
#
#                                           respondent  \
# 0                1:dharampal satyapal ltd.       ...
# 1                1:the state of assam and 3 ors  ...
# 2                1:union of india and 5 ors.     ...
# 3                1:the state of assam and anr.   ...
# 4                1:chittarlekha borah and ors.   ...
#
#                                  petitioner_advocate  \
# 0                                     mr. s c keyal
# 1                                     ms.s sultana
# 2  mr h r a choudhury                            ...
# 3  ms.r devi                                     ...
# 4                                     mr.s s sarma
#
#                                  respondent_advocate  \
# 0    mr. p baruah                                  -
# 1   mr.s b sarma                                 ...
# 2   asstt.s.g.i.                                 ...
# 3   pp, assam                                    ...
# 4                      mrs.g sarma
#
#                                                judge  bench_size  \
# 0  { mr. justice achintya malla bujor barua,  the...         2.0
# 1                  { mr. justice arup kumar goswami}         1.0
# 2  { mr. justice manish choudhury,  mr. justice m...         2.0
# 3                 { mrs. justice rumi kumari phukan}         1.0
# 4                          { mr. justice nani tagia}         1.0
#
#   chief_justice  state petitioner_business respondent_business
# 0          True   True               False                True
# 1         False   True               False               False
# 2         False   True               False               False
# 3         False   True               False               False
# 4         False   True                True               False

# %%
df.isna().sum()
# Out:
# file                   0
# cnr_num                0
# title                  0
# date                   0
# court                  0
# case_number            8
# petitioner             1
# respondent             1
# petitioner_advocate    2
# respondent_advocate    4
# judge                  5
# bench_size             5
# chief_justice          5
# state                  0
# petitioner_business    1
# respondent_business    1
# dtype: int64

# %%
df['state'].value_counts()
# Out:
# True     360
# False    140
# Name: state, dtype: int64

# %%
import csv
import textdistance

start_time = time.time()  

assam_companies = pd.read_csv('../company/Copy of Assam_2016.csv')
assam_companies_names = ik.preprocess_company_names(assam_companies.COMPANY_NAME.tolist())

# print(assam_companies_names[:5])

list_of_litigants = df[df.petitioner_business==True].loc[:,'petitioner'].tolist()  
list_of_litigants.extend(df[df.respondent_business==True].loc[:,'respondent'].tolist())
print(len(list_of_litigants))

list_of_litigants = ik.preprocess_company_names(list_of_litigants)

tf = {}
for litigant in list_of_litigants:
    for word in litigant.split():
        if word in tf:
            tf[word] += 1
        else:
            tf[word] = 1
        
    

df['max_score_petitioner'], df['business_match_petitioner'] = (np.nan, np.nan)
df.business_match_petitioner = df[df.petitioner_busi ness==True].loc[:,'petitioner'].apply(ik.match_business_tf, args=(assam_companies_names[:],tf))

# df.business_match_petitioner = df[df.petitioner_business==True].loc[:,'petitioner'].apply(ik.match_business, args=(assam_companies_names[:5],))

print(f"--- {(time.time() - start_time)} seconds ---")  # 50 companies list and 500 df takes 40s; 500, 500 takes 512s
# Out:
# 91
# --- 17583.99256157875 seconds ---

# %%
from textdistance import smith_waterman, needleman_wunsch, jaro_winkler, jaccard, levenshtein, overlap, tanimoto, cosine, bag, monge_elkan
from fuzzywuzzy import fuzz

a = 'LOAN CO OF ASSAM LTD'
b = '1:national insurance co. ltd.             regd. office at middleton street, kolkata and one of the             regional offices known as guwahati regional office,             g.s.road, bhangagarh, ghy-5 and a branch office at tezpur.,             assam.              '
# 72                  1:debashis das and anr.        ...
# 74              1:mustt sarifa begum and 7 ors     ...
# 104                1:kalpana das and 4 ors.        ...
# 107             1:smti kunja basumatary and 5 ors  ...
# 116    1:the state of assam and 16 ors. rep. by the...
# 118                1:the union of india and 3 ors  ...
# 119                1:m/s amrit kumar patel and sons...
# 128             1:tilottama ahmed and 3 ors.       ...
# 141             1:sri dhanjit das and 4 ors        ...
# 142                1:union of india and 2 ors      ...
# 158                1:smti pranita kalita and 2 ors ...
# 164                               1:sri vinay ram a...
# 165                1:md joydar ali and anr         ...
# 166                1:the state of assam and 2 ors. ...
# 171                1:tarani rajbongshi and ors     ...
# 182             1:the chief engineer, construction-...
# 217              1:hiranya kalita           s/o- sr...
# 230                1:smti moni bhengra and 2 ors   ...
# 249                1:on the death of smti. minita b...
# 253                1:on the death of smti. minita b...
# 256                 1:laldari choudhury and anr.   ...
# 263             1:union of india and 6 ors         ...
# 276                1:the state of assam and 3 ors  ...
# 279             1:the state of assam and 4 ors     ...
# 291                1:sarifa khatoon and anr.       ...
# 294             1:the state of assam and 3 ors.    ...
# 299    1:coal india ltd and 4 ors. netaji subhash r...
# 323                1:md joydar ali and anr         ...
# 328             1:sri swmkwr basumatary and 3 ors  ...
# 336                 1:m/s north eastern engineers  ...
# 345                1:md. aynal haque @ ainal haque ...
# 348             1:mst mafida begum and 5 ors       ...
# 381             1:puna gogoi and 5 ors          r/o...
# 384                  1:ashok kumar chhajer         ...
# 388                1:the state of assam and anr.   ...
# 398             1:karimuddin laskar and 3 ors      ...
# 408                1:the workmen represented by the...
# 425             1:the state of assam and 4 ors     ...
# 433                1:pradip mahajan and anr.       ...
# 444             1:smti. junu rabha and 4 ors       ...
# 453             1:sri bikash agarwalla          s/o...
# 454             1:sewali rabha and 2 ors          d...
# 459                1:smt nibedita roy and 2 ors    ...
# 469                1:ripun bhuyan and anr          ...
# 471                   1:union of india             ...
# 475                1:the state of assam and ors    ...
# 495                1:the state of assam and anr    ...
#
#                             petitioner_advocate  \
# 4                                mr.s s sarma
# 32                                 mr.s sarma
# 33                                s k goswami
# 36                              mr.d senapati
# 38                             mr. a j saikia
# 72                                 mr.b c das
# 74                              mr. r goswami
# 104                            ms.m choudhury
# 107                            mr. k k bhatta
# 116                                mr.s haque
# 118                          mr.k p maheswari
# 119                                mr. p bora
# 128                           : mr.r k bhatra
# 141                             mr. r goswami
# 142                             mr. r hussain
# 158                              mr. r c paul
# 164   sishir dutta
# 165                          ms. r d mozumdar
# 166                               mr. n c das
# 171                          ms. r d mozumdar
# 182                         : ms.a b kayastha
# 217                    . l k borah
# 230                          ms. r d mozumdar
# 249                             mr. r goswami
# 253                             mr. r goswami
# 256                               mr.r c paul
# 263                               dr. a saraf
# 276                                  mr.g das
# 279                              : ms.a gogoi
# 291                                   .l sarma
# 294                               mr. n c das
# 299                           mr.a j hazarika
# 323                          ms. r d mozumdar
# 328                          : mr. s s sharma
# 336                             ms.s senapati
# 345                        mr. s k sanganeria
# 348                           mr. s k goswami
# 381                               mr. s dutta
# 384                          mr.a k maheswari
# 388                               mr. a sarma
# 398                            mr. r k bhatra
# 408                                  mr.b das
# 425                         mr. g n sahewalla
# 433                               mr. a dutta
# 444                             mr. r goswami
# 453                                mr.s dutta
# 454                            mr. p hazarika
# 459                         mr. m k choudhury
# 469                                mr. j deka
# 471                       : mr. k p maheswari
# 475                            mr.k choudhury
# 495                            mr. v k chopra
#
#                                    respondent_advocate  \
# 4                        mrs.g sarma
# 32    mrv k barooahr-5                             ...
# 33    md.s islam , mr amarenra gogoi legal aid coun...
# 36                                                 ...
# 38                  mr. a r agarwala
# 72
# 74    mr. a r agarwala               in macapp. 530...
# 104                                                ...
# 107
# 116   sc, co-op.                                   ...
# 118   sc, nf rly                                   ...
# 119
# 128   md.a hussainr-1and2                          ...
# 141   mr. k sarma                                  ...
# 142   sc, railway                                  ...
# 158   mr s khound (r2,r3)                          ...
# 164                                                ...
# 165
# 166   ga, assam                                    ...
# 171   mr. s c pandit (r1)                          ...
# 182   mr.d k dey                                   ...
# 217
# 230   mr. b kumar (r-2)                            ...
# 249   mr. p borah                                  ...
# 253   mr. p borah                                  ...
# 256   mr.j p sarma                                 ...
# 263   asstt.s.g.i.                                 ...
# 276   ga, assam                                    ...
# 279   sc, agri. department                         ...
# 291   mr. s alim (r2)                              ...
# 294   ga, assam                                    ...
# 299   mr.m z ahmed                                 ...
# 323                mr. b k jain (r1)
# 328   mr. m j baruah (op1, op2)                    ...
# 336    mr.s bora
# 345                        mr. s dutta
# 348                  mr. z iqbal (r1-r5)
# 381   ms. s khanikar (r1)                          ...
# 384   mr.t c das                                   ...
# 388   pp, assam                                    ...
# 398           mr. b u laskar (r3,r4)
# 408   mr. j s bhattacharjee r1                     ...
# 425                            ga, assam
# 433                                                ...
# 444
# 453
# 454             mr sishir dutta (r2)
# 459   mr d k mishra                                  -
# 469   pp, assam                                    ...
# 471   sc, nf rly                                   ...
# 475                                                ...
# 495   pp, assam                                    ...
#
#                                                  judge  bench_size  \
# 4                            { mr. justice nani tagia}         1.0
# 32                                                 NaN         NaN
# 33                          { mr. justice suman shyam}         1.0
# 36                    { mr. justice kalyan rai surana}         1.0
# 38                           { mr. justice nani tagia}         1.0
# 72                          { mr. justice suman shyam}         1.0
# 74                  { mr. justice michael zothankhuma}         1.0
# 104                    { mr. justice manish choudhury}         1.0
# 107                      { mr. justice ajit borthakur}         1.0
# 116                  { mr. justice sanjay kumar medhi}         1.0
# 118                  { mr. justice arup kumar goswami}         1.0
# 119                         { mr. justice suman shyam}         1.0
# 128                  { mr. justice sanjay kumar medhi}         1.0
# 141                        { mr. justice nelson sailo}         1.0
# 142                        { mr. justice ujjal bhuyan}         1.0
# 158                 { mr. justice michael zothankhuma}         1.0
# 164                 { mr. justice michael zothankhuma}         1.0
# 165                 { mr. justice michael zothankhuma}         1.0
# 166                        { mr. justice ujjal bhuyan}         1.0
# 171                      { mr. justice ajit borthakur}         1.0
# 182                   { mr. justice kalyan rai surana}         1.0
# 217                  { mr. justice sanjay kumar medhi}         1.0
# 230                        { mr. justice nelson sailo}         1.0
# 249                { mr. justice manash ranjan pathak}         1.0
# 253                   { mr. justice kalyan rai surana}         1.0
# 256                         { mr. justice suman shyam}         1.0
# 263                { mr. justice manash ranjan pathak}         1.0
# 276                         { mr. justice suman shyam}         1.0
# 279                          { mr. justice nani tagia}         1.0
# 291                          { mr. justice nani tagia}         1.0
# 294                        { mr. justice ujjal bhuyan}         1.0
# 299                        { mr. justice ujjal bhuyan}         1.0
# 323                 { mr. justice michael zothankhuma}         1.0
# 328                          { mr. justice nani tagia}         1.0
# 336                         { mr. justice suman shyam}         1.0
# 345                    { mr. justice manish choudhury}         1.0
# 348                        { mr. justice nelson sailo}         1.0
# 381                   { mr. justice kalyan rai surana}         1.0
# 384                 { mr. justice prasanta kumar deka}         1.0
# 388                 { mrs. justice rumi kumari phukan}         1.0
# 398                    { mr. justice manish choudhury}         1.0
# 408                   { mr. justice kalyan rai surana}         1.0
# 425  { mr. justice arup kumar goswami,  the chief j...         2.0
# 433                          { mr. justice nani tagia}         1.0
# 444                         { mr. justice suman shyam}         1.0
# 453                         { mr. justice suman shyam}         1.0
# 454                 { mr. justice michael zothankhuma}         1.0
# 459  { mr. justice achintya malla bujor barua,  the...         2.0
# 469                 { mrs. justice rumi kumari phukan}         1.0
# 471                         { mr. justice suman shyam}         1.0
# 475  { mr. justice arup kumar goswami,  the chief j...         2.0
# 495                 { mrs. justice rumi kumari phukan}         1.0
#
#     chief_justice  state petitioner_business respondent_business  \
# 4           False   True                True               False
# 32            NaN   True                True                True
# 33          False  False                True                True
# 36          False   True                True               False
# 38          False   True                True               False
# 72          False   True                True               False
# 74          False  False                True               False
# 104         False  False                True               False
# 107         False  False                True               False
# 116         False   True                True                True
# 118         False   True                True               False
# 119         False  False                True               False
# 128         False   True                True               False
# 141         False  False                True               False
# 142         False   True                True               False
# 158         False  False                True               False
# 164         False  False                True               False
# 165         False   True                True               False
# 166         False   True                True               False
# 171         False  False                True               False
# 182         False  False                True               False
# 217         False  False                True               False
# 230         False   True                True               False
# 249         False  False                True               False
# 253         False  False                True               False
# 256         False   True                True               False
# 263         False   True                True               False
# 276         False   True                True               False
# 279         False   True                True                True
# 291         False   True                True               False
# 294         False   True                True               False
# 299         False   True                True                True
# 323         False   True                True               False
# 328         False   True                True               False
# 336         False  False                True               False
# 345         False   True                True               False
# 348         False  False                True               False
# 381         False  False                True                True
# 384         False  False                True               False
# 388         False   True                True               False
# 398         False   True                True               False
# 408         False  False                True               False
# 425          True   True                True               False
# 433         False   True                True               False
# 444         False   True                True                True
# 453         False  False                True               False
# 454         False  False                True               False
# 459          True   True                True               False
# 469         False   True                True               False
# 471         False   True                True               False
# 475          True   True                True               False
# 495         False   True                True                True
#
#      max_score_petitioner                  business_match_petitioner
# 4                     NaN                                   (0, nan)
# 32                    NaN  (0.01639344262295082, ROOT 2 ROUTE INDIA)
# 33                    NaN                                   (0, nan)
# 36                    NaN                                   (0, nan)
# 38                    NaN                                   (0, nan)
# 72                    NaN                                   (0, nan)
# 74                    NaN                                   (0, nan)
# 104                   NaN                                   (0, nan)
# 107                   NaN                                   (0, nan)
# 116                   NaN                                   (0, nan)
# 118                   NaN                                   (0, nan)
# 119                   NaN                                   (0, nan)
# 128                   NaN                                   (0, nan)
# 141                   NaN                  (0.25, MAJESTIC 21 INFRA)
# 142                   NaN                                   (0, nan)
# 158                   NaN                                   (0, nan)
# 164                   NaN                                   (0, nan)
# 165                   NaN                                   (0, nan)
# 166                   NaN                                   (0, nan)
# 171                   NaN                                   (0, nan)
# 182                   NaN                                   (0, nan)
# 217                   NaN                                   (0, nan)
# 230                   NaN                                   (0, nan)
# 249                   NaN  (0.01639344262295082, ROOT 2 ROUTE INDIA)
# 253                   NaN  (0.01639344262295082, ROOT 2 ROUTE INDIA)
# 256                   NaN                                   (0, nan)
# 263                   NaN                                   (0, nan)
# 276                   NaN                                   (0, nan)
# 279                   NaN                                   (0, nan)
# 291                   NaN                                   (0, nan)
# 294                   NaN                                   (0, nan)
# 299                   NaN                                   (0, nan)
# 323                   NaN                                   (0, nan)
# 328                   NaN                                   (0, nan)
# 336                   NaN                                   (0, nan)
# 345                   NaN                                   (0, nan)
# 348                   NaN                                   (0, nan)
# 381                   NaN                                   (0, nan)
# 384                   NaN                                   (0, nan)
# 388                   NaN                                   (0, nan)
# 398                   NaN                                   (0, nan)
# 408                   NaN                                   (0, nan)
# 425                   NaN                                   (0, nan)
# 433                   NaN                                   (0, nan)
# 444                   NaN                                   (0, nan)
# 453                   NaN  (0.01639344262295082, ROOT 2 ROUTE INDIA)
# 454                   NaN                                   (0, nan)
# 459                   NaN                                   (0, nan)
# 469                   NaN                                   (0, nan)
# 471                   NaN                                   (0, nan)
# 475                   NaN                                   (0, nan)
# 495                   NaN              (1.0, AB ( INDIA) MULTITRADE)

# %%
df[df.petitioner_business==True].loc[495,'petitioner']
# Out:
# '1:three leaves india pvt. ltd.             ( a company registered under the companies act) having its             registered office at jain house, g.s. road, dispur, guwahati-             781005, herein rep. by sri subash aich, s/o- late m.c. aich              '

# %%
symbols = "&-./:,-"

a = ['hello, how are you', 'mr. smith & his sons']

a = [val.replace(i, '') for i in symbols for val in a if str(val) != 'nan']
a
# Out:
# ['hello, how are you',
#  'mr. smith  his sons',
#  'hello, how are you',
#  'mr. smith & his sons',
#  'hello, how are you',
#  'mr smith & his sons',
#  'hello, how are you',
#  'mr. smith & his sons',
#  'hello, how are you',
#  'mr. smith & his sons',
#  'hello how are you',
#  'mr. smith & his sons',
#  'hello, how are you',
#  'mr. smith & his sons']

# %%
tf['aich']
# Out:
# 2

# %%
text = "maheshwar abc enterprise"
list_of_company_names = ['abcd enterprise', 'maheshwari' ]
ik.match_business_tf(text, list_of_company_names, tf)
# Out:
# 0.11111111111111116 maheshwar abcd 0 nan 0 nan 0 nan
# 0.75 abc abcd 0.11111111111111116 ('abcd', 'maheshwar') 0 nan 0 nan
# 0.0 enterprise abcd 0.75 ('abcd', 'abc') 0 nan 0 nan
# 0.09999999999999998 maheshwar enterprise 0 ('enterprise', 'enterprise') 0 nan 0 nan
# 0.0 abc enterprise 0.09999999999999998 ('enterprise', 'maheshwar') 0 nan 0 nan
# 1.0 enterprise enterprise 0.09999999999999998 ('enterprise', 'maheshwar') 0 nan 0 nan
# ------ enterprise 252 enterprise 1.0 ('enterprise', 'enterprise') 0 nan 0 nan
# 0.9 maheshwar maheshwari 0 nan 0 nan 0.003968253968253968 abcd enterprise
# 0.09999999999999998 abc maheshwari 0.9 ('maheshwari', 'maheshwar') 0 nan 0.003968253968253968 abcd enterprise
# 0.09999999999999998 enterprise maheshwari 0.9 ('maheshwari', 'maheshwar') 0 nan 0.003968253968253968 abcd enterprise
# ------ maheshwar 3 maheshwari 0.9 ('maheshwari', 'maheshwar') 0 nan 0.003968253968253968 abcd enterprise
# (0.3, 'maheshwari')

# %%
df
# Out:
#               file             cnr_num  \
# 0    100006976.txt   gahc010142142019
# 1    100009202.txt   gahc010130082013
# 2    100013560.txt   gahc010076622019
# 3    100015777.txt   gahc010021642017
# 4    100020544.txt   gahc010133782017
# ..             ...                 ...
# 495   10161782.txt   gahc010109872019
# 496   10162356.txt   gahc010270392019
# 497  101627330.txt   gahc010043902019
# 498  101629518.txt   gahc010151842018
# 499  101638130.txt   gahc010255942019
#
#                                                  title               date  \
# 0    The Commissioner Of Central Goods ... vs Dhara...   25 October, 2019
# 1          Jufiul Huda vs The State Of Assam And 3 Ors     11 March, 2019
# 2             Amena Khatun vs Union Of India And 5 Ors     29 April, 2019
# 3        Raj Kumar Singh vs The State Of Assam And Anr       3 June, 2019
# 4    National Insurance Co. Ltd vs Chittarlekha Bor...     30 April, 2019
# ..                                                 ...                ...
# 495  Three Leaves India Pvt. Ltd vs The State Of As...      12 June, 2019
# 496            Upendra Chaudhury vs The State Of Assam  29 November, 2019
# 497  Md. Farukh Shah And 8 Ors vs On The Death Of M...   6 December, 2019
# 498        Samsuddin Ali vs The State Of Assam And Anr    4 January, 2019
# 499  Smt. Padumi Deori And Anr vs Shantanu Sarmah B...  15 November, 2019
#
#                   court                       case_number  \
# 0    Gauhati High Court  case no. : i.a.(civil) 2085/2019
# 1    Gauhati High Court        case no. : wp(c) 2866/2013
# 2    Gauhati High Court        case no. : wp(c) 2410/2019
# 3    Gauhati High Court    case no. : crl.rev.p. 140/2017
# 4    Gauhati High Court  case no. : i.a.(civil) 2261/2017
# ..                  ...                               ...
# 495  Gauhati High Court       case no. : crl.l.p. 46/2019
# 496  Gauhati High Court           case no. : ab 3943/2019
# 497  Gauhati High Court  case no. : i.a.(civil) 1644/2019
# 498  Gauhati High Court      case no. : crl.pet. 658/2018
# 499  Gauhati High Court           case no. : crp 156/2019
#
#                                             petitioner  \
# 0    1:the commissioner of central goods and servic...
# 1    1:jufiul huda             s/o nurul huda r/o s...
# 2    1:amena khatun             w/o. hamed ali @ ab...
# 3    1:raj kumar singh             s/o sri hetrm si...
# 4    1:national insurance co. ltd.             regd...
# ..                                                 ...
# 495  1:three leaves india pvt. ltd.             ( a...
# 496  1:upendra chaudhury             s/o ratneswar ...
# 497  1:md. farukh shah and 8 ors.          s/o late...
# 498  1:samsuddin ali             s/o lt. usman ali ...
# 499  1:smt. padumi deori and anr.              w/o....
#
#                                             respondent  \
# 0                  1:dharampal satyapal ltd.       ...
# 1                  1:the state of assam and 3 ors  ...
# 2                  1:union of india and 5 ors.     ...
# 3                  1:the state of assam and anr.   ...
# 4                  1:chittarlekha borah and ors.   ...
# ..                                                 ...
# 495                1:the state of assam and anr    ...
# 496                1:the state of assam            ...
# 497                1:on the death of moina begum, h...
# 498                1:the state of assam and anr.   ...
# 499                 1:shantanu sarmah boruah       ...
#
#                                    petitioner_advocate  \
# 0                                       mr. s c keyal
# 1                                       ms.s sultana
# 2    mr h r a choudhury                            ...
# 3    ms.r devi                                     ...
# 4                                       mr.s s sarma
# ..                                                 ...
# 495                                   mr. v k chopra
# 496                                     mr. n sharma
# 497                                       mr. a dhar
# 498                                         mr d das
# 499                                    mr. a ganguly
#
#                                    respondent_advocate  \
# 0      mr. p baruah                                  -
# 1     mr.s b sarma                                 ...
# 2     asstt.s.g.i.                                 ...
# 3     pp, assam                                    ...
# 4                        mrs.g sarma
# ..                                                 ...
# 495   pp, assam                                    ...
# 496   pp, assam                                    ...
# 497
# 498   pp, assam                                    ...
# 499   mr. a sattar                                 ...
#
#                                                  judge  bench_size  \
# 0    { mr. justice achintya malla bujor barua,  the...         2.0
# 1                    { mr. justice arup kumar goswami}         1.0
# 2    { mr. justice manish choudhury,  mr. justice m...         2.0
# 3                   { mrs. justice rumi kumari phukan}         1.0
# 4                            { mr. justice nani tagia}         1.0
# ..                                                 ...         ...
# 495                 { mrs. justice rumi kumari phukan}         1.0
# 496                    { mr. justice manish choudhury}         1.0
# 497                   { mr. justice kalyan rai surana}         1.0
# 498                       { mr. justice mir alfaz ali}         1.0
# 499                 { mr. justice prasanta kumar deka}         1.0
#
#     chief_justice  state petitioner_business respondent_business  \
# 0            True   True               False                True
# 1           False   True               False               False
# 2           False   True               False               False
# 3           False   True               False               False
# 4           False   True                True               False
# ..            ...    ...                 ...                 ...
# 495         False   True                True                True
# 496         False   True               False               False
# 497         False  False               False               False
# 498         False   True               False               False
# 499         False  False               False               False
#
#      max_score_petitioner      business_match_petitioner
# 0                     NaN                            NaN
# 1                     NaN                            NaN
# 2                     NaN                            NaN
# 3                     NaN                            NaN
# 4                     NaN                       (0, nan)
# ..                    ...                            ...
# 495                   NaN  (1.0, AB ( INDIA) MULTITRADE)
# 496                   NaN                            NaN
# 497                   NaN                            NaN
# 498                   NaN                            NaN
# 499                   NaN                            NaN
#
# [500 rows x 18 columns]

# %%
# Out:
# 21.991148575128552
