# %%
import tweepy

CONSUMER_KEY = 'ewKyyTmJYRgfaNErddbBuwlCR'
CONSUMER_SECRET = 'xUpo4rKed0ctUevXGkFqdL8d2gtKbgbtmNtIa3iZ8Qu1NfwOfl'
ACCESS_TOKEN = '38210202-UmgFHncTyvgnfrF2uhK2NxDhrAWJOoGOaFY1EznWH'
ACCESS_TOKEN_SECRET = 'qEsxcNdsQ1K4oX2sr16Z1mx99UyddOu860deRDPwdMuZK'

# Authenticate to Twitter
auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_TOKEN,ACCESS_TOKEN_SECRET)
api = tweepy.API(auth)

# %%
# test authentication
try:
    api.verify_credentials()
    print("Authentication OK")
except:
    print("Error during authentication")
# Out:
# Authentication OK

# %%
# (api.followers('JusticeGulzar'))
for item in (api.followers()):
    print(item)
    print('-------')
# Out:
# User(_api=<tweepy.api.API object at 0x000001C88B070948>, _json={'id': 1242276604098695168, 'id_str': '1242276604098695168', 'name': 'Tanay Gosavi', 'screen_name': 'gosavi_tanay', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 4, 'friends_count': 14, 'listed_count': 0, 'created_at': 'Tue Mar 24 02:26:46 +0000 2020', 'favourites_count': 1, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 7, 'lang': None, 'status': {'created_at': 'Mon Jul 20 13:43:48 +0000 2020', 'id': 1285208790921392130, 'id_str': '1285208790921392130', 'text': '@SidShirole @SidShirole if anyone setting up covid centers need sanitizers pls let me know.  I can give at cost pri… https://t.co/gTrX34fzd4', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'SidShirole', 'name': 'Siddharth Shirole', 'id': 70121276, 'id_str': '70121276', 'indices': 
# ...
